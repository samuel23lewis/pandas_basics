# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_25424\1492400551.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('data1.csv')
print(df.to_string())
# Out:
#     number name address   rand
# 0        1   AB      AB  585.0
# 1        2   AC     NaN    NaN
# 2        3   AD      AD  410.0
# 3        4  NaN      AE  875.0
# 4        5   AF      AF  669.0
# 5        6   AG      AG  340.0
# 6        7   AH      AH  531.0
# 7        8   AI      AI    NaN
# 8        9   AJ      AJ  937.0
# 9       10   AK     NaN  317.0
# 10      11   AL      AL  458.0
# 11      12   AM      AM  196.0
# 12      13   AN      AN  700.0
# 13      14   AO      AO  935.0
# 14      15   AP      AP  364.0
# 15      16  NaN      AQ  193.0
# 16      17   AR     NaN    NaN
# 17      18   AS      AS  958.0
# 18      19   AT      AT  892.0
# 19      20   AU      AU   17.0
# 20      21   AV      AV    6.0
# 21      22   AW      AW  994.0
# 22      23   AX     NaN  376.0
# 23      24   AY      AY  324.0
# 24      25   AZ      AZ  150.0
# 25      26   BA      BA  377.0
# 26      27  NaN      BB    NaN
# 27      28   BC      BC  937.0
# 28      29   BD      BD  149.0
# ...

# %%
#ploting and visualizing the data
df.plot()
plt.show()

# %%
#scatter ploting
# the X and Y should be after the coloumn names
df.plot(kind='scatter',x='number',y='rand')
plt.show()

# %%
#histogram
df['rand'].plot(kind='hist')
plt.show()
